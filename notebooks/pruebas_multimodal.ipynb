# %%
from src.multimodal.image_extraction import extract_images_from_pdf
from pathlib import Path

# %%
pdfs = list(Path("data/raw").glob("*.pdf"))
[p.name for p in pdfs]

# %%
if pdfs:
    extracted = extract_images_from_pdf(str(pdfs[0]))
    print(f"Imágenes extraídas: {len(extracted)}")
    extracted[:5]
else:
    print("No hay PDFs en data/raw")

# %%
if extracted:
    for img in extracted[:5]:
        print(img)
